# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Ganti dengan lokasi file data Anda
data_file = "data_convert.csv"

# Membaca data menjadi dataframe Pandas
df = pd.read_csv(data_file)

# Pilih kolom sensor measurement yang akan dinormalisasi dan diplot
sensor_column = 'sensor measurement 2'

# Normalisasi Z-Score
scaler = StandardScaler()
z_score_scaled_column = scaler.fit_transform(df[[sensor_column]])

# Membuat histogram untuk data yang sudah dinormalisasi
plt.figure(figsize=(8, 6))
plt.hist(z_score_scaled_column, bins=50, color='r', alpha=0.7)
plt.title("Histogram for Z-Score Normalization")
plt.xlabel("Z-Score Normalized Values")
plt.ylabel("Frequency")
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Ganti dengan lokasi file data Anda
data_file = "data_convert.csv"

# Membaca data menjadi dataframe Pandas
df = pd.read_csv(data_file)

# Pilih semua kolom sensor measurement
sensor_columns = [
    'sensor measurement 1', 'sensor measurement 2', 'sensor measurement 3',
    'sensor measurement 4', 'sensor measurement 5', 'sensor measurement 6',
    'sensor measurement 7', 'sensor measurement 8', 'sensor measurement 9',
    'sensor measurement 10', 'sensor measurement 11', 'sensor measurement 12',
    'sensor measurement 13', 'sensor measurement 14', 'sensor measurement 15',
    'sensor measurement 16', 'sensor measurement 17', 'sensor measurement 18',
    'sensor measurement 19', 'sensor measurement 20', 'sensor measurement 21'
]

# Normalisasi Z-Score pada semua kolom sensor
scaler = StandardScaler()
df[sensor_columns] = scaler.fit_transform(df[sensor_columns])

# Membuat histogram untuk distribusi data yang sudah dinormalisasi
plt.figure(figsize=(12, 6))
for i, column in enumerate(sensor_columns):
    plt.subplot(3, 7, i + 1)
    plt.hist(df[column], bins=50, color='r', alpha=0.7)
    plt.title(f"Sensor {i + 1}")
    plt.xlabel("Z-Score Normalized Values")
    plt.ylabel("Frequency")
    plt.grid()

plt.tight_layout()

# Menyimpan data yang sudah dinormalisasi ke dalam file CSV
normalized_data_file = "normalized_data.xls"
df.to_csv(normalized_data_file, index=False)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ganti dengan lokasi file data yang sudah dinormalisasi
normalized_data_file = "normalized_data.csv"

# Membaca data yang sudah dinormalisasi menjadi dataframe Pandas
df_normalized = pd.read_csv(normalized_data_file)

# Pilih semua kolom sensor measurement (kolom 6 hingga akhir)
sensor_columns = df_normalized.columns[6:]

# Membuat box plot untuk masing-masing kolom sensor yang sudah dinormalisasi
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df_normalized[sensor_columns], orient="v")
plt.xticks(rotation=90)
plt.title("Box Plot for Normalized Sensor Data")
plt.xlabel("Sensor Measurements")
plt.ylabel("Z-Score Normalized Values")
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ganti dengan lokasi file data yang sudah dinormalisasi
normalized_data_file = "normalized_data.csv"

# Membaca data yang sudah dinormalisasi menjadi dataframe Pandas
df_normalized = pd.read_csv(normalized_data_file)

# Pilih kolom sensor yang ingin Anda buat box plot
sensor_column = 'sensor measurement 7'  # Ganti dengan nama kolom sensor yang Anda inginkan

# Membuat box plot untuk kolom sensor yang dipilih
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.boxplot(x=df_normalized[sensor_column], orient="v", color="skyblue")
plt.title(f"Box Plot for {sensor_column}")
plt.ylabel("Z-Score Normalized Values")
plt.tight_layout()

plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# Ganti dengan lokasi file data Anda
data_file = "data_convert.csv"

# Membaca data menjadi dataframe Pandas
df = pd.read_csv(data_file)

# Pilih kolom-kolom yang akan tetap ada
selected_columns = [
    'unit number', 'time in cycles', 'operational setting 1', 'operational setting 2', 'operational setting 3'
]

# Pilih kolom-kolom sensor yang ingin dihapus
sensor_columns_to_remove = [
    'sensor measurement 1', 'sensor measurement 5', 'sensor measurement 6',
    'sensor measurement 10', 'sensor measurement 16', 'sensor measurement 18',
    'sensor measurement 19'
]

# Hapus kolom-kolom sensor yang dipilih
df = df.drop(sensor_columns_to_remove, axis=1)

# Normalisasi Z-Score pada kolom-kolom sensor yang tersisa
sensor_columns = df.columns[5:]  # Mengambil semua kolom sensor yang tersisa
scaler = StandardScaler()
df[sensor_columns] = scaler.fit_transform(df[sensor_columns])

# Simpan hasil normalisasi ke dalam file CSV
normalized_data_file = "normalized_data_fix.csv"  # Ganti dengan nama file CSV yang Anda inginkan
df.to_csv(normalized_data_file, index=False)

# Membuat box plot untuk masing-masing kolom sensor yang sudah dinormalisasi
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df[sensor_columns], orient="v")
plt.xticks(rotation=90)
plt.title("Box Plot for Normalized Sensor Data")
plt.xlabel("Sensor Measurements")
plt.ylabel("Z-Score Normalized Values")
plt.tight_layout()

plt.show()
